# %%
# Importing packages
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
import folium
from folium.plugins import HeatMap
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('onlinenews_train.csv')

# %%
df.columns
# Out:
# Index(['url', 'timedelta', 'n_tokens_title', 'n_tokens_content',
#        'n_unique_tokens', 'n_non_stop_words', 'n_non_stop_unique_tokens',
#        'num_hrefs', 'num_self_hrefs', 'num_imgs', 'num_videos',
#        'average_token_length', 'num_keywords', 'data_channel_is_lifestyle',
#        'data_channel_is_entertainment', 'data_channel_is_bus',
#        'data_channel_is_socmed', 'data_channel_is_tech',
#        'data_channel_is_world', 'kw_min_min', 'kw_max_min', 'kw_avg_min',
#        'kw_min_max', 'kw_max_max', 'kw_avg_max', 'kw_min_avg', 'kw_max_avg',
#        'kw_avg_avg', 'self_reference_min_shares', 'self_reference_max_shares',
#        'self_reference_avg_sharess', 'weekday_is_monday', 'weekday_is_tuesday',
#        'weekday_is_wednesday', 'weekday_is_thursday', 'weekday_is_friday',
#        'weekday_is_saturday', 'weekday_is_sunday', 'is_weekend', 'LDA_00',
#        'LDA_01', 'LDA_02', 'LDA_03', 'LDA_04', 'global_subjectivity',
#        'global_sentiment_polarity', 'global_rate_positive_words',
#        'global_rate_negative_words', 'rate_positive_words',
#        'rate_negative_words', 'avg_positive_polarity', 'min_positive_polarity',
#        'max_positive_polarity', 'avg_negative_polarity',
#        'min_negative_polarity', 'max_negative_polarity', 'title_subjectivity',
#        'title_sentiment_polarity', 'abs_title_subjectivity',
#        'abs_title_sentiment_polarity', 'shares', 'RowID'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32000 entries, 0 to 31999
# Data columns (total 62 columns):
# url                              31837 non-null object
# timedelta                        31847 non-null float64
# n_tokens_title                   31829 non-null float64
# n_tokens_content                 31838 non-null float64
# n_unique_tokens                  31839 non-null float64
# n_non_stop_words                 31795 non-null float64
# n_non_stop_unique_tokens         31842 non-null float64
# num_hrefs                        31837 non-null float64
# num_self_hrefs                   31815 non-null float64
# num_imgs                         31831 non-null float64
# num_videos                       31826 non-null float64
# average_token_length             31840 non-null float64
# num_keywords                     31822 non-null float64
# data_channel_is_lifestyle        31850 non-null float64
# data_channel_is_entertainment    31863 non-null float64
# data_channel_is_bus              31853 non-null float64
# data_channel_is_socmed           31849 non-null float64
# data_channel_is_tech             31842 non-null float64
# data_channel_is_world            31841 non-null float64
# kw_min_min                       31833 non-null float64
# kw_max_min                       31842 non-null float64
# kw_avg_min                       31851 non-null float64
# kw_min_max                       31814 non-null float64
# kw_max_max                       31827 non-null float64
# kw_avg_max                       31830 non-null float64
# kw_min_avg                       31837 non-null float64
# kw_max_avg                       31830 non-null float64
# kw_avg_avg                       31831 non-null float64
# self_reference_min_shares        31824 non-null float64
# self_reference_max_shares        31850 non-null float64
# self_reference_avg_sharess       31838 non-null float64
# weekday_is_monday                31846 non-null float64
# weekday_is_tuesday               31826 non-null float64
# weekday_is_wednesday             31837 non-null float64
# weekday_is_thursday              31822 non-null float64
# weekday_is_friday                31846 non-null float64
# weekday_is_saturday              31858 non-null float64
# weekday_is_sunday                31846 non-null float64
# is_weekend                       31837 non-null float64
# LDA_00                           31830 non-null float64
# LDA_01                           31833 non-null float64
# LDA_02                           31837 non-null float64
# LDA_03                           31857 non-null float64
# LDA_04                           31849 non-null float64
# global_subjectivity              31847 non-null float64
# global_sentiment_polarity        31850 non-null float64
# global_rate_positive_words       31824 non-null float64
# global_rate_negative_words       31853 non-null float64
# rate_positive_words              31822 non-null float64
# rate_negative_words              31833 non-null float64
# avg_positive_polarity            31850 non-null float64
# min_positive_polarity            31853 non-null float64
# max_positive_polarity            31840 non-null float64
# avg_negative_polarity            31829 non-null float64
# min_negative_polarity            31851 non-null float64
# max_negative_polarity            31847 non-null float64
# title_subjectivity               31846 non-null float64
# title_sentiment_polarity         31846 non-null float64
# abs_title_subjectivity           31823 non-null float64
# abs_title_sentiment_polarity     31862 non-null float64
# shares                           31822 non-null float64
# RowID                            31859 non-null float64
# dtypes: float64(61), object(1)
# memory usage: 15.1+ MB

# %%
df.head()
# Out:
#                                                  url  timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...      731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...      731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...      731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...      731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/      731.0
#
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0            12.0             219.0         0.663594               1.0
# 1             9.0             255.0         0.604743               1.0
# 2             9.0             211.0         0.575130               1.0
# 3             9.0             531.0         0.503788               1.0
# 4            13.0            1072.0         0.415646               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  ...    \
# 0                  0.815385        4.0             2.0       1.0  ...
# 1                  0.791946        3.0             1.0       1.0  ...
# 2                  0.663866        3.0             1.0       1.0  ...
# 3                  0.665635        9.0             0.0       1.0  ...
# 4                  0.540890       19.0            19.0      20.0  ...
#
#    max_positive_polarity  avg_negative_polarity  min_negative_polarity  \
# 0                    0.7              -0.350000                 -0.600
# 1                    0.7              -0.118750                 -0.125
# 2                    1.0              -0.466667                 -0.800
# 3                    0.8              -0.369697                 -0.600
# 4                    1.0              -0.220192                 -0.500
#
#    max_negative_polarity  title_subjectivity  title_sentiment_polarity  \
# 0              -0.200000            0.500000                 -0.187500
# 1              -0.100000            0.000000                  0.000000
# 2              -0.133333            0.000000                  0.000000
# 3              -0.166667            0.000000                  0.000000
# 4              -0.050000            0.454545                  0.136364
#
#    abs_title_subjectivity  abs_title_sentiment_polarity  shares  RowID
# 0                0.000000                      0.187500   593.0    NaN
# 1                0.500000                      0.000000   711.0    2.0
# 2                0.500000                      0.000000  1500.0    3.0
# 3                0.500000                      0.000000  1200.0    4.0
# 4                0.045455                      0.136364   505.0    5.0
#
# [5 rows x 62 columns]

# %%
# counting null values
df.isnull().sum().sort_values(ascending = False)
# Out:
# n_non_stop_words                 205
# kw_min_max                       186
# num_self_hrefs                   185
# num_keywords                     178
# weekday_is_thursday              178
# shares                           178
# rate_positive_words              178
# abs_title_subjectivity           177
# global_rate_positive_words       176
# self_reference_min_shares        176
# weekday_is_tuesday               174
# num_videos                       174
# kw_max_max                       173
# avg_negative_polarity            171
# n_tokens_title                   171
# kw_max_avg                       170
# kw_avg_max                       170
# LDA_00                           170
# num_imgs                         169
# kw_avg_avg                       169
# kw_min_min                       167
# rate_negative_words              167
# LDA_01                           167
# weekday_is_wednesday             163
# LDA_02                           163
# is_weekend                       163
# kw_min_avg                       163
# num_hrefs                        163
# url                              163
# n_tokens_content                 162
#                                 ...
# max_positive_polarity            160
# average_token_length             160
# data_channel_is_world            159
# kw_max_min                       158
# n_non_stop_unique_tokens         158
# data_channel_is_tech             158
# title_subjectivity               154
# weekday_is_monday                154
# title_sentiment_polarity         154
# weekday_is_sunday                154
# weekday_is_friday                154
# max_negative_polarity            153
# global_subjectivity              153
# timedelta                        153
# LDA_04                           151
# data_channel_is_socmed           151
# global_sentiment_polarity        150
# self_reference_max_shares        150
# data_channel_is_lifestyle        150
# avg_positive_polarity            150
# kw_avg_min                       149
# min_negative_polarity            149
# data_channel_is_bus              147
# min_positive_polarity            147
# global_rate_negative_words       147
# LDA_03                           143
# weekday_is_saturday              142
# RowID                            141
# abs_title_sentiment_polarity     138
# data_channel_is_entertainment    137
# Length: 62, dtype: int64

# %%
features = normalized_df.columns.difference(['shares'])
features = ['LDA_00', 'LDA_01', 'LDA_02', 'LDA_03', 'LDA_04',
       'abs_title_sentiment_polarity', 'abs_title_subjectivity',
       'average_token_length', 'avg_negative_polarity',
       'avg_positive_polarity', 'data_channel_is_bus',
       'data_channel_is_entertainment', 'data_channel_is_lifestyle',
       'data_channel_is_socmed', 'data_channel_is_tech',
       'data_channel_is_world', 'global_rate_negative_words',
       'global_rate_positive_words', 'global_sentiment_polarity',
       'global_subjectivity', 'is_weekend', 'kw_avg_avg', 'kw_avg_max',
       'kw_avg_min', 'kw_max_avg', 'kw_max_max', 'kw_max_min', 'kw_min_avg',
       'kw_min_max', 'kw_min_min', 'max_negative_polarity',
       'max_positive_polarity', 'min_negative_polarity',
       'min_positive_polarity', 'n_non_stop_unique_tokens', 'n_non_stop_words',
       'n_tokens_content', 'n_tokens_title', 'n_unique_tokens', 'num_hrefs',
       'num_imgs', 'num_keywords', 'num_self_hrefs', 'num_videos',
       'rate_negative_words', 'rate_positive_words',
       'self_reference_avg_sharess', 'self_reference_max_shares',
       'self_reference_min_shares', 'timedelta', 'title_sentiment_polarity',
       'title_subjectivity', 'weekday_is_friday', 'weekday_is_monday',
       'weekday_is_saturday', 'weekday_is_sunday', 'weekday_is_thursday',
       'weekday_is_tuesday', 'weekday_is_wednesday'] #15k

features = ['LDA_01', 'LDA_02', 'LDA_03', 'LDA_04',
       'abs_title_sentiment_polarity', 'abs_title_subjectivity',
       'average_token_length', 'avg_negative_polarity',
       'avg_positive_polarity', 'data_channel_is_bus',
       'data_channel_is_entertainment', 'data_channel_is_lifestyle',
       'data_channel_is_socmed', 'data_channel_is_tech',
       'data_channel_is_world', 'global_rate_negative_words',
       'global_subjectivity', 'is_weekend', 'kw_avg_avg', 'kw_avg_max',
       'kw_avg_min', 'kw_max_avg', 'kw_max_max', 'kw_max_min', 'kw_min_avg',
       'kw_min_max', 'max_negative_polarity',
       'max_positive_polarity', 'min_negative_polarity',
       'n_tokens_content', 'n_tokens_title', 'num_hrefs',
       'num_imgs', 'num_keywords', 'num_self_hrefs', 'num_videos',
       'rate_negative_words', 'rate_positive_words',
       'self_reference_avg_sharess', 'self_reference_max_shares',
       'self_reference_min_shares', 'timedelta', 'title_sentiment_polarity',
       'title_subjectivity', 'weekday_is_friday', 'weekday_is_monday',
       'weekday_is_saturday', 'weekday_is_sunday', 'weekday_is_thursday',
       'weekday_is_tuesday', 'weekday_is_wednesday'] #11293

features = ['LDA_01', 'LDA_02', 'LDA_03', 'LDA_04',
       'abs_title_sentiment_polarity',
       'avg_negative_polarity',
       'avg_positive_polarity', 'data_channel_is_bus',
       'data_channel_is_entertainment',
       'data_channel_is_tech',
       'data_channel_is_world', 'global_rate_negative_words',
       'global_subjectivity', 'is_weekend', 'kw_avg_avg', 'kw_avg_max',
       'kw_avg_min', 'kw_max_avg', 'kw_max_max', 'kw_max_min', 'kw_min_avg',
        'max_negative_polarity',
       'max_positive_polarity', 'min_negative_polarity',
       'n_tokens_content',  'num_hrefs',
       'num_imgs', 'num_keywords', 'num_videos',
       'self_reference_avg_sharess', 'self_reference_max_shares',
       'self_reference_min_shares', 'title_sentiment_polarity',
       'title_subjectivity',  'weekday_is_monday',
       'weekday_is_saturday',
       'weekday_is_tuesday']

features1=features[:]
features1.append('shares')

df1 = df[features1]
df1=df1.dropna()
df1
normalized_df=(df1[df1.columns.difference(['shares'])]-df1[df1.columns.difference(['shares'])].min())/(df1[df1.columns.difference(['shares'])].max()-df1[df1.columns.difference(['shares'])].min())
normalized_df['shares']=df1['shares']
normalized_df
# Out:
#          LDA_01    LDA_02    LDA_03    LDA_04  abs_title_sentiment_polarity  \
# 0      0.411183  0.043483  0.044582  0.043273                      0.187500
# 1      0.054400  0.054453  0.054131  0.053927                      0.000000
# 2      0.036234  0.036252  0.036015  0.735758                      0.000000
# 3      0.455772  0.537665  0.031230  0.030815                      0.000000
# 4      0.031298  0.031060  0.030870  0.954956                      0.136364
# 5      0.333397  0.024164  0.024012  0.675785                      0.214286
# 6      0.124683  0.021766  0.021626  0.889971                      0.000000
# 7      0.163844  0.264604  0.024011  0.605467                      0.500000
# 8      0.031500  0.031154  0.032085  0.490096                      0.000000
# 9      0.043479  0.913041  0.043219  0.043143                      0.000000
# 10     0.312292  0.435685  0.282930  0.026966                      0.000000
# 11     0.031058  0.031082  0.031025  0.955023                      0.000000
# 12     0.028189  0.027378  0.328779  0.532887                      1.000000
# 14     0.031320  0.031059  0.956352  0.030940                      0.550000
# 15     0.036233  0.942026  0.036017  0.035952                      0.250000
# 17     0.036233  0.036232  0.036015  0.035951                      0.000000
# 18     0.217792  0.036366  0.036091  0.318600                      0.714286
# 20     0.021745  0.021759  0.021618  0.992136                      0.000000
# 21     0.031063  0.739851  0.030873  0.251741                      0.000000
# 22     0.252917  0.031060  0.030873  0.429514                      0.000000
# 23     0.036235  0.760854  0.216101  0.035953                      0.400000
# 26     0.024552  0.144960  0.143666  0.742929                      0.000000
# 28     0.021773  0.021755  0.021618  0.992142                      0.000000
# 29     0.036237  0.036234  0.036017  0.035953                      0.500000
# 30     0.184053  0.031056  0.031855  0.030816                      0.000000
# 31     0.217723  0.031060  0.031063  0.769777                      0.000000
# 32     0.333548  0.024164  0.024012  0.675636                      0.000000
# 33     0.199499  0.293398  0.518214  0.036209                      1.000000
# 34     0.027726  0.027327  0.027098  0.768775                      0.000000
# 35     0.022426  0.022301  0.130467  0.882248                      0.350000
# ...         ...       ...       ...       ...                           ...
# 31966  0.043479  0.913040  0.043218  0.043145                      0.000000
# 31967  0.054357  0.054349  0.054023  0.862809                      0.136364
# 31968  0.036233  0.036269  0.036015  0.036920                      0.000000
# 31969  0.036257  0.036316  0.216158  0.754615                      0.000000
# 31970  0.054352  0.325995  0.054022  0.053980                      0.000000
# 31971  0.169247  0.300040  0.155733  0.430460                      0.000000
# 31972  0.045011  0.043480  0.906048  0.043142                      0.000000
# 31973  0.036234  0.036272  0.036015  0.035971                      0.000000
# 31974  0.043754  0.043889  0.685127  0.261841                      0.000000
# 31975  0.575310  0.031057  0.415986  0.030816                      0.000000
# 31976  0.043481  0.043479  0.043218  0.905960                      0.000000
# 31978  0.027176  0.298472  0.027012  0.026966                      0.000000
# 31979  0.418306  0.537348  0.044087  0.043141                      1.000000
# 31980  0.027832  0.192128  0.804483  0.026965                      0.850000
# 31981  0.941979  0.036232  0.036089  0.035951                      0.000000
# 31982  0.036234  0.942026  0.036015  0.035953                      0.000000
# 31983  0.031060  0.962722  0.030872  0.030818                      0.300000
# 31984  0.056742  0.054509  0.861816  0.053926                      0.000000
# 31985  0.027263  0.027175  0.972313  0.026964                      0.225000
# 31986  0.036236  0.942014  0.036017  0.035959                      0.000000
# 31988  0.031074  0.031142  0.031284  0.031179                      0.136364
# 31989  0.570539  0.352257  0.055142  0.053926                      0.000000
# 31990  0.031140  0.803523  0.031083  0.187504                      0.000000
# 31991  0.043490  0.043771  0.043223  0.347590                      0.000000
# 31992  0.024427  0.748666  0.024010  0.263495                      0.000000
# 31994  0.280643  0.024155  0.616263  0.136965                      0.500000
# 31995  0.021741  0.021743  0.021610  0.774930                      0.000000
# 31996  0.027500  0.027174  0.972066  0.026963                      0.000000
# 31997  0.024159  0.024156  0.024011  0.982649                      0.000000
# 31999  0.186748  0.031056  0.030870  0.800786                      0.000000
#
#        avg_negative_polarity  avg_positive_polarity  data_channel_is_bus  \
# 0                   0.650000               0.378636                  0.0
# 1                   0.881250               0.286915                  1.0
# 2                   0.533333               0.495833                  1.0
# 3                   0.630303               0.385965                  0.0
# 4                   0.779808               0.411127                  0.0
# 5                   0.805000               0.350610                  0.0
# 6                   0.775521               0.402039                  0.0
# 7                   0.757222               0.427720                  0.0
# 8                   0.875000               0.566667                  0.0
# 9                   0.761905               0.298413                  0.0
# 10                  0.584936               0.404480                  0.0
# 11                  0.737500               0.435000                  0.0
# 12                  0.689583               0.375510                  0.0
# 14                  0.861310               0.249091                  0.0
# 15                  0.779850               0.343070                  0.0
# 17                  0.855357               0.381847                  1.0
# 18                  0.875000               0.277778                  0.0
# 20                  0.793452               0.408245                  0.0
# 21                  0.891667               0.150000                  0.0
# 22                  0.769737               0.416343                  0.0
# 23                  1.000000               0.281061                  0.0
# 26                  0.736111               0.556558                  0.0
# 28                  0.822500               0.333297                  0.0
# 29                  0.786111               0.340572                  1.0
# 30                  0.755556               0.291941                  1.0
# 31                  0.658333               0.298033                  0.0
# 32                  0.822222               0.438908                  0.0
# 33                  0.770833               0.419439                  0.0
# 34                  0.600000               0.422182                  0.0
# 35                  0.679861               0.400551                  0.0
# ...                      ...                    ...                  ...
# 31966               0.619430               0.350634                  0.0
# 31967               0.850000               0.353546                  0.0
# 31968               0.602778               0.275000                  1.0
# 31969               0.875000               0.313766                  0.0
# 31970               1.000000               0.136364                  1.0
# 31971               0.595000               0.337169                  0.0
# 31972               0.806111               0.269394                  0.0
# 31973               0.576515               0.459753                  1.0
# 31974               0.754167               0.358636                  0.0
# 31975               0.753750               0.448913                  0.0
# 31976               0.600000               0.410417                  0.0
# 31978               0.844444               0.404040                  1.0
# 31979               0.606244               0.439685                  0.0
# 31980               0.768750               0.463287                  0.0
# 31981               0.716667               0.298295                  0.0
# 31982               0.775758               0.315927                  0.0
# 31983               0.636574               0.390374                  0.0
# 31984               0.576284               0.418515                  0.0
# 31985               1.000000               0.000000                  0.0
# 31986               0.700000               0.262500                  0.0
# 31988               0.822727               0.293711                  0.0
# 31989               0.611173               0.391155                  0.0
# 31990               0.825000               0.196320                  0.0
# 31991               0.887500               0.100000                  1.0
# 31992               0.441667               0.357143                  0.0
# 31994               0.783333               0.399167                  0.0
# 31995               0.770000               0.353810                  0.0
# 31996               1.000000               0.000000                  0.0
# 31997               0.724802               0.384454                  0.0
# 31999               0.671535               0.367095                  0.0
#
#        data_channel_is_entertainment  data_channel_is_tech   ...     \
# 0                                1.0                   0.0   ...
# 1                                0.0                   0.0   ...
# 2                                0.0                   0.0   ...
# 3                                1.0                   0.0   ...
# 4                                0.0                   1.0   ...
# 5                                0.0                   1.0   ...
# 6                                0.0                   0.0   ...
# 7                                0.0                   1.0   ...
# 8                                0.0                   1.0   ...
# 9                                0.0                   0.0   ...
# 10                               0.0                   0.0   ...
# 11                               0.0                   0.0   ...
# 12                               0.0                   0.0   ...
# 14                               0.0                   0.0   ...
# 15                               0.0                   0.0   ...
# 17                               0.0                   0.0   ...
# 18                               0.0                   0.0   ...
# 20                               0.0                   1.0   ...
# 21                               0.0                   0.0   ...
# 22                               0.0                   1.0   ...
# 23                               0.0                   0.0   ...
# 26                               0.0                   1.0   ...
# 28                               0.0                   0.0   ...
# 29                               0.0                   0.0   ...
# 30                               0.0                   0.0   ...
# 31                               0.0                   1.0   ...
# 32                               0.0                   1.0   ...
# 33                               0.0                   0.0   ...
# 34                               0.0                   0.0   ...
# 35                               0.0                   0.0   ...
# ...                              ...                   ...   ...
# 31966                            0.0                   0.0   ...
# 31967                            0.0                   0.0   ...
# 31968                            0.0                   0.0   ...
# 31969                            0.0                   0.0   ...
# 31970                            0.0                   0.0   ...
# 31971                            0.0                   1.0   ...
# 31972                            1.0                   0.0   ...
# 31973                            0.0                   0.0   ...
# 31974                            0.0                   0.0   ...
# 31975                            0.0                   0.0   ...
# 31976                            0.0                   1.0   ...
# 31978                            0.0                   0.0   ...
# 31979                            1.0                   0.0   ...
# 31980                            1.0                   0.0   ...
# 31981                            1.0                   0.0   ...
# 31982                            0.0                   0.0   ...
# 31983                            0.0                   0.0   ...
# 31984                            1.0                   0.0   ...
# 31985                            0.0                   0.0   ...
# 31986                            0.0                   0.0   ...
# 31988                            0.0                   0.0   ...
# 31989                            1.0                   0.0   ...
# 31990                            0.0                   0.0   ...
# 31991                            0.0                   0.0   ...
# 31992                            0.0                   0.0   ...
# 31994                            0.0                   0.0   ...
# 31995                            0.0                   1.0   ...
# 31996                            0.0                   0.0   ...
# 31997                            0.0                   1.0   ...
# 31999                            0.0                   1.0   ...
#
#        num_videos  self_reference_avg_sharess  self_reference_max_shares  \
# 0        0.000000                    0.000588                   0.000588
# 1        0.000000                    0.000000                   0.000000
# 2        0.000000                    0.001089                   0.001089
# 3        0.000000                    0.000000                   0.000000
# 4        0.000000                    0.003737                   0.018973
# 5        0.000000                    0.010079                   0.010079
# 6        0.000000                    0.003737                   0.018973
# 7        0.000000                    0.003737                   0.018973
# 8        0.000000                    0.000000                   0.000000
# 9        0.010989                    0.000000                   0.000000
# 10       0.000000                    0.000000                   0.000000
# 11       0.000000                    0.000000                   0.000000
# 12       0.000000                    0.015949                   0.019210
# 14       0.000000                    0.005692                   0.005692
# 15       0.000000                    0.000000                   0.000000
# 17       0.000000                    0.000000                   0.000000
# 18       0.000000                    0.005929                   0.005929
# 20       0.000000                    0.003737                   0.018973
# 21       0.010989                    0.000835                   0.000835
# 22       0.000000                    0.003737                   0.018973
# 23       0.000000                    0.019092                   0.019092
# 26       0.000000                    0.002965                   0.002965
# 28       0.000000                    0.000000                   0.000000
# 29       0.000000                    0.000000                   0.000000
# 30       0.010989                    0.007233                   0.007233
# 31       0.000000                    0.000000                   0.000000
# 32       0.000000                    0.000000                   0.000000
# 33       0.000000                    0.000000                   0.000000
# 34       0.000000                    0.000000                   0.000000
# 35       0.000000                    0.007352                   0.007352
# ...           ...                         ...                        ...
# 31966    0.000000                    0.002489                   0.006048
# 31967    0.021978                    0.001897                   0.003083
# 31968    0.021978                    0.010583                   0.019922
# 31969    0.021978                    0.003202                   0.003913
# 31970    0.000000                    0.009961                   0.018736
# 31971    0.000000                    0.002045                   0.003320
# 31972    0.000000                    0.003996                   0.006048
# 31973    0.000000                    0.001215                   0.001304
# 31974    0.032967                    0.002727                   0.002727
# 31975    0.000000                    0.006522                   0.006522
# 31976    0.000000                    0.016483                   0.016483
# 31978    0.000000                    0.001779                   0.001779
# 31979    0.274725                    0.001938                   0.003557
# 31980    0.010989                    0.004301                   0.017194
# 31981    0.010989                    0.005692                   0.005692
# 31982    0.010989                    0.002134                   0.002134
# 31983    0.000000                    0.000000                   0.000000
# 31984    0.285714                    0.003948                   0.010910
# 31985    0.010989                    0.000000                   0.000000
# 31986    0.000000                    0.002016                   0.002016
# 31988    0.000000                    0.002965                   0.002965
# 31989    0.362637                    0.003380                   0.004980
# 31990    0.000000                    0.002055                   0.003202
# 31991    0.010989                    0.006522                   0.006522
# 31992    0.000000                    0.001373                   0.002016
# 31994    0.010989                    0.018380                   0.018380
# 31995    0.000000                    0.007411                   0.012451
# 31996    0.010989                    0.000000                   0.000000
# 31997    0.021978                    0.001423                   0.001423
# 31999    0.021978                    0.004388                   0.004388
#
#        self_reference_min_shares  title_sentiment_polarity  \
# 0                       0.000588                  0.406250
# 1                       0.000000                  0.500000
# 2                       0.001089                  0.500000
# 3                       0.000000                  0.500000
# 4                       0.000646                  0.568182
# 5                       0.010079                  0.607143
# 6                       0.000646                  0.500000
# 7                       0.000646                  0.750000
# 8                       0.000000                  0.500000
# 9                       0.000000                  0.500000
# 10                      0.000000                  0.500000
# 11                      0.000000                  0.500000
# 12                      0.012688                  0.000000
# 14                      0.005692                  0.775000
# 15                      0.000000                  0.375000
# 17                      0.000000                  0.500000
# 18                      0.005929                  0.142857
# 20                      0.000646                  0.500000
# 21                      0.000835                  0.500000
# 22                      0.000646                  0.500000
# 23                      0.019092                  0.700000
# 26                      0.002965                  0.500000
# 28                      0.000000                  0.500000
# 29                      0.000000                  0.750000
# 30                      0.007233                  0.500000
# 31                      0.000000                  0.500000
# 32                      0.000000                  0.500000
# 33                      0.000000                  1.000000
# 34                      0.000000                  0.500000
# 35                      0.007352                  0.675000
# ...                          ...                       ...
# 31966                   0.000819                  0.500000
# 31967                   0.001186                  0.568182
# 31968                   0.005218                  0.500000
# 31969                   0.002490                  0.500000
# 31970                   0.001186                  0.500000
# 31971                   0.000770                  0.500000
# 31972                   0.000687                  0.500000
# 31973                   0.001127                  0.500000
# 31974                   0.002727                  0.500000
# 31975                   0.006522                  0.500000
# 31976                   0.016483                  0.500000
# 31978                   0.001779                  0.500000
# 31979                   0.000867                  1.000000
# 31980                   0.000910                  0.925000
# 31981                   0.005692                  0.500000
# 31982                   0.002134                  0.500000
# 31983                   0.000000                  0.350000
# 31984                   0.000853                  0.500000
# 31985                   0.000000                  0.612500
# 31986                   0.002016                  0.500000
# 31988                   0.002965                  0.568182
# 31989                   0.000950                  0.500000
# 31990                   0.000908                  0.500000
# 31991                   0.006522                  0.500000
# 31992                   0.000994                  0.500000
# 31994                   0.018380                  0.750000
# 31995                   0.002372                  0.500000
# 31996                   0.000000                  0.500000
# 31997                   0.001423                  0.500000
# 31999                   0.004388                  0.500000
#
#        title_subjectivity  weekday_is_monday  weekday_is_saturday  \
# 0                0.500000                1.0                  0.0
# 1                0.000000                1.0                  0.0
# 2                0.000000                1.0                  0.0
# 3                0.000000                1.0                  0.0
# 4                0.454545                1.0                  0.0
# 5                0.642857                1.0                  0.0
# 6                0.000000                1.0                  0.0
# 7                1.000000                1.0                  0.0
# 8                0.125000                1.0                  0.0
# 9                0.000000                1.0                  0.0
# 10               0.000000                1.0                  0.0
# 11               0.000000                1.0                  0.0
# 12               1.000000                1.0                  0.0
# 14               0.750000                1.0                  0.0
# 15               0.750000                1.0                  0.0
# 17               0.000000                1.0                  0.0
# 18               0.857143                1.0                  0.0
# 20               0.000000                1.0                  0.0
# 21               0.000000                1.0                  0.0
# 22               0.000000                1.0                  0.0
# 23               0.450000                1.0                  0.0
# 26               0.000000                1.0                  0.0
# 28               0.000000                1.0                  0.0
# 29               0.500000                1.0                  0.0
# 30               0.000000                1.0                  0.0
# 31               0.000000                1.0                  0.0
# 32               0.000000                1.0                  0.0
# 33               1.000000                1.0                  0.0
# 34               0.000000                1.0                  0.0
# 35               0.550000                1.0                  0.0
# ...                   ...                ...                  ...
# 31966            0.000000                0.0                  0.0
# 31967            0.500000                0.0                  0.0
# 31968            0.000000                0.0                  0.0
# 31969            0.100000                0.0                  0.0
# 31970            0.000000                0.0                  0.0
# 31971            0.000000                0.0                  0.0
# 31972            0.000000                0.0                  0.0
# 31973            0.000000                0.0                  0.0
# 31974            0.000000                0.0                  0.0
# 31975            0.000000                0.0                  0.0
# 31976            0.000000                0.0                  0.0
# 31978            0.000000                0.0                  0.0
# 31979            1.000000                0.0                  0.0
# 31980            1.000000                0.0                  0.0
# 31981            0.000000                0.0                  0.0
# 31982            0.000000                0.0                  0.0
# 31983            0.100000                0.0                  0.0
# 31984            0.000000                0.0                  0.0
# 31985            0.600000                0.0                  0.0
# 31986            0.000000                0.0                  0.0
# 31988            0.454545                0.0                  0.0
# 31989            0.000000                0.0                  0.0
# 31990            0.000000                0.0                  0.0
# 31991            0.500000                0.0                  0.0
# 31992            0.000000                0.0                  0.0
# 31994            0.750000                0.0                  0.0
# 31995            0.000000                0.0                  0.0
# 31996            0.000000                0.0                  0.0
# 31997            0.125000                0.0                  0.0
# 31999            0.000000                0.0                  0.0
#
#        weekday_is_tuesday   shares
# 0                     0.0    593.0
# 1                     0.0    711.0
# 2                     0.0   1500.0
# 3                     0.0   1200.0
# 4                     0.0    505.0
# 5                     0.0    855.0
# 6                     0.0    556.0
# 7                     0.0    891.0
# 8                     0.0   3600.0
# 9                     0.0    710.0
# 10                    0.0   2200.0
# 11                    0.0   1900.0
# 12                    0.0    823.0
# 14                    0.0    761.0
# 15                    0.0   1600.0
# 17                    0.0   3100.0
# 18                    0.0   5700.0
# 20                    0.0   2800.0
# 21                    0.0    598.0
# 22                    0.0    445.0
# 23                    0.0   1500.0
# 26                    0.0   1500.0
# 28                    0.0    462.0
# 29                    0.0    425.0
# 30                    0.0   3200.0
# 31                    0.0   3900.0
# 32                    0.0    480.0
# 33                    0.0    573.0
# 34                    0.0   3600.0
# 35                    0.0    343.0
# ...                   ...      ...
# 31966                 0.0   1200.0
# 31967                 0.0    995.0
# 31968                 0.0  23300.0
# 31969                 0.0    890.0
# 31970                 0.0   1100.0
# 31971                 0.0    947.0
# 31972                 0.0   1500.0
# 31973                 0.0    671.0
# 31974                 0.0   1400.0
# 31975                 0.0    815.0
# 31976                 0.0   1300.0
# 31978                 0.0    700.0
# 31979                 0.0    630.0
# 31980                 0.0   2500.0
# 31981                 0.0   1100.0
# 31982                 0.0   1100.0
# 31983                 0.0   2600.0
# 31984                 0.0    582.0
# 31985                 0.0    695.0
# 31986                 0.0    769.0
# 31988                 0.0    629.0
# 31989                 0.0   1200.0
# 31990                 0.0   2400.0
# 31991                 0.0    817.0
# 31992                 0.0    885.0
# 31994                 0.0   6900.0
# 31995                 0.0   3200.0
# 31996                 0.0   2800.0
# 31997                 0.0  17200.0
# 31999                 0.0   1900.0
#
# [26515 rows x 38 columns]

# %% [markdown]
# ### Evaluation

# %%
from sklearn.model_selection import train_test_split

# %%
## Doing a test train split
train_data,test_data = train_test_split(normalized_df,train_size = 0.8,random_state = 12345
                                       )

# %%
X_train = train_data[features]
y_train = train_data['shares']

# %%
from sklearn import linear_model

# %%
from sklearn.linear_model import LinearRegression

# %%
## Applying simple linear regression model
lr = LinearRegression()

# %%
## fitting the train dataset
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
from sklearn import metrics 

print('Intercept: {}'.format(lr.intercept_))
print('Coefficients: {}'.format(lr.coef_))

pred = lr.predict(test_data[features])

rmsecm = float(format(np.sqrt(metrics.mean_squared_error(test_data['shares'],pred)),'.3f'))
rmsecm
# Out:
# Intercept: 2895.378424125065
# Coefficients: [-5.96210473e+02 -9.64231827e+02  5.16404593e+02 -8.14789492e+02
#  -4.56197397e+01 -2.65792440e+03 -1.42581860e+03  4.04731097e+01
#  -7.28454102e+02  2.47407458e+02 -3.11862141e+01 -1.24428547e+03
#   6.82836725e+02  9.87312271e+01  8.24201859e+04 -1.16559973e+03
#  -1.14024749e+04 -7.49818537e+04 -8.18076218e+02  3.49428069e+04
#  -1.40185191e+03 -8.93528112e+02 -3.24682878e+02 -4.21351702e+01
#   3.72119496e+03  4.20680152e+03  4.85140692e+02  6.72782503e+02
#   3.64194618e+03 -1.71863681e+04  7.67523411e+03  4.07425251e+04
#   9.79531457e+01  6.77874578e+01  4.12791653e+02  7.32046329e+02
#  -4.62395255e+01]
# 7658.913

# %%
normalized_df.iloc[:, list(range(5,10)) + [-1]].corr(method ='pearson')
# Out:
#                                avg_negative_polarity  avg_positive_polarity  \
# avg_negative_polarity                       1.000000              -0.198870
# avg_positive_polarity                      -0.198870               1.000000
# data_channel_is_bus                         0.067211              -0.030497
# data_channel_is_entertainment              -0.126933               0.043378
# data_channel_is_tech                        0.141102              -0.017732
# shares                                     -0.050726               0.025526
#
#                                data_channel_is_bus  \
# avg_negative_polarity                     0.067211
# avg_positive_polarity                    -0.030497
# data_channel_is_bus                       1.000000
# data_channel_is_entertainment            -0.203502
# data_channel_is_tech                     -0.221232
# shares                                   -0.010734
#
#                                data_channel_is_entertainment  \
# avg_negative_polarity                              -0.126933
# avg_positive_polarity                               0.043378
# data_channel_is_bus                                -0.203502
# data_channel_is_entertainment                       1.000000
# data_channel_is_tech                               -0.225913
# shares                                             -0.015648
#
#                                data_channel_is_tech    shares
# avg_negative_polarity                      0.141102 -0.050726
# avg_positive_polarity                     -0.017732  0.025526
# data_channel_is_bus                       -0.221232 -0.010734
# data_channel_is_entertainment             -0.225913 -0.015648
# data_channel_is_tech                       1.000000 -0.015975
# shares                                    -0.015975  1.000000

# %%
pred_df = pd.read_csv('onlinenews_test.csv')
pred_df1=pred_df[features]

pred_df1=(pred_df1-df1[df1.columns.difference(['shares'])].min())/(df1[df1.columns.difference(['shares'])].max()-df1[df1.columns.difference(['shares'])].min())

pred = lr.predict(pred_df1[features])
df8 = pd.DataFrame(pred,columns=['shares'])
df8['RowID'] = pred_df['RowID']

df8
df8.to_csv('manishdsilva.csv',index=False)

# %%
pred_df1.isnull().sum().sort_values(ascending = False)
# Out:
# RowID                            0
# data_channel_is_tech             0
# kw_avg_min                       0
# kw_avg_max                       0
# kw_avg_avg                       0
# is_weekend                       0
# global_subjectivity              0
# global_rate_negative_words       0
# data_channel_is_world            0
# data_channel_is_entertainment    0
# weekday_is_tuesday               0
# data_channel_is_bus              0
# avg_positive_polarity            0
# avg_negative_polarity            0
# abs_title_sentiment_polarity     0
# LDA_04                           0
# LDA_03                           0
# LDA_02                           0
# kw_max_avg                       0
# kw_max_max                       0
# kw_max_min                       0
# kw_min_avg                       0
# weekday_is_saturday              0
# weekday_is_monday                0
# title_subjectivity               0
# title_sentiment_polarity         0
# self_reference_min_shares        0
# self_reference_max_shares        0
# self_reference_avg_sharess       0
# num_videos                       0
# num_keywords                     0
# num_imgs                         0
# num_hrefs                        0
# n_tokens_content                 0
# min_negative_polarity            0
# max_positive_polarity            0
# max_negative_polarity            0
# LDA_01                           0
# dtype: int64
